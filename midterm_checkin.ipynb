# %% [markdown]
# # Initial Visualization of data plus data preparation

# %% [markdown]
# ## Dataset

# %%
 = pd.read_csv('')
# Out:
#   Cell In[1], line 1
#     = pd.read_csv('')
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Data Transformations

# %% [markdown]
# ## Visualization
